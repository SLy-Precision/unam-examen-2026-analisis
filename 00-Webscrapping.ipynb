# %%
from bs4 import BeautifulSoup as soup
from urllib.request import Request, urlopen
import pandas as pd

def get_info_from_results_url(url, df, career, faculty_name, area):
    """
    Extracts information from a results page and appends it to the provided DataFrame list.

    Args:
    - url (str): The URL of the results page to scrape.
    - df (list): A list to which the scraped data will be appended as dictionaries.
    - career (str): The name of the career related to the results.
    - faculty_name (str): The name of the faculty offering the career.
    - area (str): The area of study.

    Returns:
    - None: The function modifies the df list in place by appending dictionaries with the extracted data.
    """
    req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
    webpage = urlopen(req).read()
    page_soup = soup(webpage, "html.parser")
    container = page_soup.findAll("tr")

    for element in container:
        values = element.find_all("td")
        if len(values) > 2:
            df.append({
                'Area': area,
                'Career': career,
                'Faculty': faculty_name,
                'Scores': values[1].text.strip(),
                'Accepted': values[2].text.strip() == 'S'
            })

# Function to get the information for all the careers
def get_info_from_area_url(url, df):
    """
    Extracts career and faculty information from an area page and retrieves detailed results for each career.

    Args:
    - url (str): The URL of the area page to scrape.
    - df (list): A list to which the scraped data from results pages will be appended.

    Returns:
    - None: The function modifies the df list in place by appending dictionaries with the extracted data from results pages.
    """
    req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
    area = url[53]
    webpage = urlopen(req).read()
    page_soup = soup(webpage, "html.parser")
    containers = page_soup.findAll("div", "post-preview")

    for container in containers:
        career = container.find("h3").text.strip()
        faculties = container.find("p", class_="post-meta")
        links = faculties.find_all("a")

        for link in links:
            faculty_name = link.text.strip()
            href = link["href"]

            full_link = 'https://www.dgae.unam.mx/Licenciatura2024/resultados/' + href
            get_info_from_results_url(full_link, df, career, faculty_name, area)


# Initialize an empty list for storing the data
df = []

# Collect data from each Area
get_info_from_area_url('https://www.dgae.unam.mx/Licenciatura2024/resultados/15.html', df)
get_info_from_area_url('https://www.dgae.unam.mx/Licenciatura2024/resultados/25.html', df)
get_info_from_area_url('https://www.dgae.unam.mx/Licenciatura2024/resultados/35.html', df)
get_info_from_area_url('https://www.dgae.unam.mx/Licenciatura2024/resultados/45.html', df)

# Convert the list to a DataFrame and save as JSON Lines
df = pd.DataFrame(df, columns=['Area', 'Career', 'Faculty', 'Scores', 'Accepted'])
df.to_json('data.json', orient='records')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[38], line 70
#      67 df = []
#      69 # Collect data from each Area
# ---> 70 get_info_from_area_url('https://www.dgae.unam.mx/Licenciatura2024/resultados/15.html', df)
#      71 get_info_from_area_url('https://www.dgae.unam.mx/Licenciatura2024/resultados/25.html', df)
#      72 get_info_from_area_url('https://www.dgae.unam.mx/Licenciatura2024/resultados/35.html', df)
#
# Cell In[38], line 49, in get_info_from_area_url(url, df)
#      47 req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
#      48 area = url[53]
# ---> 49 webpage = urlopen(req).read()
#      50 page_soup = soup(webpage, "html.parser")
#      51 containers = page_soup.findAll("div", "post-preview")
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/urllib/request.py:187, in urlopen(url, data, timeout, context)
# ...

# %%
# Enlaces de resultados de exámenes de admisión de la UNAM 2017-2026. A partir de 2021, sólo hay un examen por año (Licenciatura). Los codigos 15 corresponden a Área 1, 25 a Área 2, 35 a Área 3 y 45 a Área 4. El area 1 es Físico-Matemáticas e Ingenierías, el área 2 es Biológicas, Químicas y de la Salud, el área 3 es Ciencias Sociales y el área 4 es Humanidades y de las Artes.

ENLACES_AREA = {
    "2017_Febrero": {
        "15": "https://www.dgae.unam.mx/Febrero2017/resultados/15.html",
        "25": "https://www.dgae.unam.mx/Febrero2017/resultados/25.html",
        "35": "https://www.dgae.unam.mx/Febrero2017/resultados/35.html",
        "45": "https://www.dgae.unam.mx/Febrero2017/resultados/45.html",
    },
    "2017_Junio": {
        "15": "https://www.dgae.unam.mx/Junio2017/resultados/15.html",
        "25": "https://www.dgae.unam.mx/Junio2017/resultados/25.html",
        "35": "https://www.dgae.unam.mx/Junio2017/resultados/35.html",
        "45": "https://www.dgae.unam.mx/Junio2017/resultados/45.html",
    },
    "2018_Febrero": {
        "15": "https://www.dgae.unam.mx/Febrero2018/resultados/15.html",
        "25": "https://www.dgae.unam.mx/Febrero2018/resultados/25.html",
        "35": "https://www.dgae.unam.mx/Febrero2018/resultados/35.html",
        "45": "https://www.dgae.unam.mx/Febrero2018/resultados/45.html",
    },
    "2018_Junio": {
        "15": "https://www.dgae.unam.mx/Junio2018/resultados/15.html",
        "25": "https://www.dgae.unam.mx/Junio2018/resultados/25.html",
        "35": "https://www.dgae.unam.mx/Junio2018/resultados/35.html",
        "45": "https://www.dgae.unam.mx/Junio2018/resultados/45.html",
    },
    "2019_Febrero": {
        "15": "https://www.dgae.unam.mx/Febrero2019/resultados/15.html",
        "25": "https://www.dgae.unam.mx/Febrero2019/resultados/25.html",
        "35": "https://www.dgae.unam.mx/Febrero2019/resultados/35.html",
        "45": "https://www.dgae.unam.mx/Febrero2019/resultados/45.html",
    },
    "2019_Junio": {
        "15": "https://www.dgae.unam.mx/Junio2019/resultados/15.html",
        "25": "https://www.dgae.unam.mx/Junio2019/resultados/25.html",
        "35": "https://www.dgae.unam.mx/Junio2019/resultados/35.html",
        "45": "https://www.dgae.unam.mx/Junio2019/resultados/45.html",
    },
    "2020_Febrero": {
        "15": "https://www.dgae.unam.mx/Febrero2020/resultados/15.html",
        "25": "https://www.dgae.unam.mx/Febrero2020/resultados/25.html",
        "35": "https://www.dgae.unam.mx/Febrero2020/resultados/35.html",
        "45": "https://www.dgae.unam.mx/Febrero2020/resultados/45.html",
    },
    "2020_Junio": {
        "15": "https://www.dgae.unam.mx/Junio2020/resultados/15.html",
        "25": "https://www.dgae.unam.mx/Junio2020/resultados/25.html",
        "35": "https://www.dgae.unam.mx/Junio2020/resultados/35.html",
        "45": "https://www.dgae.unam.mx/Junio2020/resultados/45.html",
    },
    "2021_Licenciatura": {
        "15": "https://www.dgae.unam.mx/Licenciatura2021/resultados/15.html",
        "25": "https://www.dgae.unam.mx/Licenciatura2021/resultados/25.html",
        "35": "https://www.dgae.unam.mx/Licenciatura2021/resultados/35.html",
        "45": "https://www.dgae.unam.mx/Licenciatura2021/resultados/45.html",
    },
    "2022_Licenciatura": {
        "15": "https://www.dgae.unam.mx/Licenciatura2022/resultados/15.html",
        "25": "https://www.dgae.unam.mx/Licenciatura2022/resultados/25.html",
        "35": "https://www.dgae.unam.mx/Licenciatura2022/resultados/35.html",
        "45": "https://www.dgae.unam.mx/Licenciatura2022/resultados/45.html",
    },
    "2023_Licenciatura": {
        "15": "https://www.dgae.unam.mx/Licenciatura2023/resultados/15.html",
        "25": "https://www.dgae.unam.mx/Licenciatura2023/resultados/25.html",
        "35": "https://www.dgae.unam.mx/Licenciatura2023/resultados/35.html",
        "45": "https://www.dgae.unam.mx/Licenciatura2023/resultados/45.html",
    },
    "2024_Licenciatura": {
        "15": "https://www.dgae.unam.mx/Licenciatura2024/resultados/15.html",
        "25": "https://www.dgae.unam.mx/Licenciatura2024/resultados/25.html",
        "35": "https://www.dgae.unam.mx/Licenciatura2024/resultados/35.html",
        "45": "https://www.dgae.unam.mx/Licenciatura2024/resultados/45.html",
    },
    "2025_Licenciatura": {
        "15": "https://www.dgae.unam.mx/Licenciatura2025/resultados/15.html",
        "25": "https://www.dgae.unam.mx/Licenciatura2025/resultados/25.html",
        "35": "https://www.dgae.unam.mx/Licenciatura2025/resultados/35.html",
        "45": "https://www.dgae.unam.mx/Licenciatura2025/resultados/45.html",
    },
    "2026_Licenciatura": {
        "15": "https://www.dgae.unam.mx/Licenciatura2026/resultados/15.html",
        "25": "https://www.dgae.unam.mx/Licenciatura2026/resultados/25.html",
        "35": "https://www.dgae.unam.mx/Licenciatura2026/resultados/35.html",
        "45": "https://www.dgae.unam.mx/Licenciatura2026/resultados/45.html",
    },
}

NOMBRES_AREA = {
    "15": "Área 1 - Físico-Matemáticas e Ingenierías",
    "25": "Área 2 - Biológicas, Químicas y de la Salud",
    "35": "Área 3 - Ciencias Sociales",
    "45": "Área 4 - Humanidades y de las Artes",
}
